# %% [markdown]
# # Strings
# Text is a string data type. Any data type written as text is a string. Any data under single, double or triple quote are strings. There are different string methods and built-in functions to deal with string data types. To check the length of a string use the len() method.

# %%
# Creating String
letter = 'p'
print(letter)
print(len(letter))

Greet = "Hello World"
print(Greet)
print(len(Greet))
# Out:
# p
# 1
# Hello World
# 11

# %%
# Multi-Line Strings
multiline_string = '''I am a teacher and enjoy teaching.
I didn't find anything as rewarding as empowering people.
That is why I created 30 days of python.'''
print(multiline_string)

# Another way of doing the same thing
multiline_string = """I am a teacher and enjoy teaching.
I didn't find anything as rewarding as empowering people.
That is why I created 30 days of python."""
print(multiline_string)
# Out:
# I am a teacher and enjoy teaching.
# I didn't find anything as rewarding as empowering people.
# That is why I created 30 days of python.
# I am a teacher and enjoy teaching.
# I didn't find anything as rewarding as empowering people.
# That is why I created 30 days of python.

# %%
# String Concatenation
first_name = 'Hello'
last_name = 'World'
space = ''
name = first_name + space +last_name
print(name)

print(len(first_name))  # 8
print(len(last_name))   # 7
print(len(first_name) > len(last_name)) # True
print(len(name)) # 16
# Out:
# HelloWorld
# 5
# 5
# False
# 10

# %%
#Escape Sequences in Strings

print('I hope everyone is enjoying the Python Challenge.\nAre you?')
print('Days\tTopics\tExercises') # adding tab space or 4 spaces
print('Day 1\t5\t5')
print('Day 2\t6\t20')
print('Day 3\t5\t23')
print('Day 4\t1\t35')
print('This is a backslash  symbol (\\)') # To write a backslash
print('In every programming language it starts with \"Hello, World!\"') # to write a double quote inside a single quote
# Out:
# I hope everyone is enjoying the Python Challenge.
# Are you?
# Days	Topics	Exercises
# Day 1	5	5
# Day 2	6	20
# Day 3	5	23
# Day 4	1	35
# This is a backslash  symbol (\)
# In every programming language it starts with "Hello, World!"

# %%
#String Formating
first_name = 'Asabeneh'
last_name = 'Yetayeh'
language = 'Python'
formated_string = 'I am {} {}. I teach {}'.format(first_name, last_name, language)
print(formated_string)
a = 4
b = 3

print('{} + {} = {}'.format(a, b, a + b))
print('{} - {} = {}'.format(a, b, a - b))
print('{} * {} = {}'.format(a, b, a * b))
print('{} / {} = {:.2f}'.format(a, b, a / b)) # limits it to two digits after decimal
print('{} % {} = {}'.format(a, b, a % b))
print('{} // {} = {}'.format(a, b, a // b))
print('{} ** {} = {}'.format(a, b, a ** b))

# Strings  and numbers
radius = 10
pi = 3.14
area = pi * radius ** 2
formated_string = 'The area of a circle with a radius {} is {:.2f}.'.format(radius, area) # 2 digits after decimal
print(formated_string)
# Out:
# I am Asabeneh Yetayeh. I teach Python
# 4 + 3 = 7
# 4 - 3 = 1
# 4 * 3 = 12
# 4 / 3 = 1.33
# 4 % 3 = 1
# 4 // 3 = 1
# 4 ** 3 = 64
# The area of a circle with a radius 10 is 314.00.

# %%
# String Interpolation
a = 4
b = 3
print(f'{a} + {b} = {a +b}')
print(f'{a} - {b} = {a - b}')
print(f'{a} * {b} = {a * b}')
print(f'{a} / {b} = {a / b:.2f}')
print(f'{a} % {b} = {a % b}')
print(f'{a} // {b} = {a // b}')
print(f'{a} ** {b} = {a ** b}')
# Out:
# 4 + 3 = 7
# 4 - 3 = 1
# 4 * 3 = 12
# 4 / 3 = 1.33
# 4 % 3 = 1
# 4 // 3 = 1
# 4 ** 3 = 64

# %%
# Accesing charecters in strings by index
language = 'Python'
first_letter = language[0]
print(first_letter)
second_letter = language[1]
print(second_letter)
last_index = len(language) - 1
print(language[last_index])
# Out:
# P
# y
# n

# %%
language = 'Python'
last_letter = language[-1]
print(last_letter)
second_last = language[-2]
print(second_last)
# Out:
# n
# o

# %%
# Slicing Python Strings
language = 'Python'
print(language[0:3]) # starts at zero index and up to 3 but not include 3
print(language[3:6])
print(language[-3:])
print(language[3:])
# Out:
# Pyt
# hon
# hon
# hon

# %%
# reverse a string
greet = 'Hello World'
print(greet[::-1])
# Out:
# dlroW olleH

# %%
# Skipping Charceters
language = 'Python'
print(language[0:6:2])# Skips 2
# Out:
# Pto

# %%
# Capitalize Methods
challenge = 'thirty days of python'
print(challenge.capitalize())
# Out:
# Thirty days of python

# %%
#Count()
print(challenge.count('y'))
print(challenge.count('y',7,14)) #count(substring/target, startindex, endindex)
print(challenge.count('th'))
# Out:
# 3
# 1
# 2

# %%
#Endswith
print(challenge.endswith('on'))
print(challenge.endswith('thon'))
# Out:
# True
# True

# %%
#Expandtabs=replaces tab charecters with spaces
challenge = 'thirty\tdays\tof\tpython'
print(challenge.expandtabs())
print(challenge.expandtabs(10))
# Out:
# thirty  days    of      python
# thirty    days      of        python

# %%
#find= finds the charecter
challenge = 'thirty days of python'
print(challenge.find('y'))  # 5
print(challenge.find('th')) # 0
# Out:
# 5
# 0
